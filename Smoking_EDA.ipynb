# %% [markdown]
# <a href="https://colab.research.google.com/github/sujata533/sujata533/blob/main/Smoking_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# data manipulation
import pandas as pd

# data transformation
import numpy as np

# visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data

smoke = pd.read_csv('/content/smoking_data.csv')
smoke.head(3)
# Out:
#         Country  Year  Total Smokers (Millions)  Smoking Prevalence (%)  \
# 0  South Africa  2010                     279.6                    21.5
# 1  South Africa  2022                      41.8                    10.2
# 2  South Africa  2017                     262.0                    30.7
#
#    Male Smokers (%)  Female Smokers (%)  \
# 0              13.3                 8.2
# 1               7.5                 2.7
# 2              22.1                 8.6
#
#    Cigarette Consumption (Billion Units) Top Cigarette Brand in Country  \
# 0                                 2415.7               Peter Stuyvesant
# 1                                   97.0               Peter Stuyvesant
# 2                                  161.5               Peter Stuyvesant
#
#    Brand Market Share (%)  Smoking-Related Deaths  Tobacco Tax Rate (%)  \
# 0                    21.3                  461574                  32.9
# 1                    46.6                   57945                  42.9
# ...

# %%
smoke.shape
# Out:
# (150, 12)

# %%
smoke.columns.to_list()
# Out:
# ['Country',
#  'Year',
#  'Total Smokers (Millions)',
#  'Smoking Prevalence (%)',
#  'Male Smokers (%)',
#  'Female Smokers (%)',
#  'Cigarette Consumption (Billion Units)',
#  'Top Cigarette Brand in Country',
#  'Brand Market Share (%)',
#  'Smoking-Related Deaths',
#  'Tobacco Tax Rate (%)',
#  'Smoking Ban Policy']

# %%
smoke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Country                                150 non-null    object
#  1   Year                                   150 non-null    int64
#  2   Total Smokers (Millions)               150 non-null    float64
#  3   Smoking Prevalence (%)                 150 non-null    float64
#  4   Male Smokers (%)                       150 non-null    float64
#  5   Female Smokers (%)                     150 non-null    float64
#  6   Cigarette Consumption (Billion Units)  150 non-null    float64
#  7   Top Cigarette Brand in Country         150 non-null    object
#  8   Brand Market Share (%)                 150 non-null    float64
#  9   Smoking-Related Deaths                 150 non-null    int64
# ...

# %%
#  statistical summary
smoke.describe(include='all').T
# Out:
#                                        count unique           top freq  \
# Country                                  150     20  South Africa   11
# Year                                   150.0    NaN           NaN  NaN
# Total Smokers (Millions)               150.0    NaN           NaN  NaN
# Smoking Prevalence (%)                 150.0    NaN           NaN  NaN
# Male Smokers (%)                       150.0    NaN           NaN  NaN
# Female Smokers (%)                     150.0    NaN           NaN  NaN
# Cigarette Consumption (Billion Units)  150.0    NaN           NaN  NaN
# Top Cigarette Brand in Country           150     17      Marlboro   24
# Brand Market Share (%)                 150.0    NaN           NaN  NaN
# Smoking-Related Deaths                 150.0    NaN           NaN  NaN
# Tobacco Tax Rate (%)                   150.0    NaN           NaN  NaN
# Smoking Ban Policy                       102      2       Partial   65
#
# ...

# %%
pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.4/400.4 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 22.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 69.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 47.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 6.4 MB/s eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(smoke, title='Smoke Trends Summary', explorative=True)

profile.to_file('smoke_summary.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
